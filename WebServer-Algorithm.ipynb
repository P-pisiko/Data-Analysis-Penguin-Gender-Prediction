# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
pengu  = sns.load_dataset('penguins')

# %%
pengu.drop("island",axis=1,inplace=True)

# %%
pengu["species"].replace(["Adelie", "Chinstrap", "Gentoo"], [0, 1, 2], inplace=True)
pengu["sex"].replace(["Male", "Female"], [0, 1], inplace=True)
# Out:
# C:\Users\T-Box\AppData\Local\Temp\ipykernel_8600\4203444556.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   pengu["species"].replace(["Adelie", "Chinstrap", "Gentoo"], [0, 1, 2], inplace=True)
# ...

# %%
pengu.dropna(inplace=True,axis=0)

# %%
pengu
# Out:
#      species  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0          0            39.1           18.7              181.0       3750.0
# 1          0            39.5           17.4              186.0       3800.0
# 2          0            40.3           18.0              195.0       3250.0
# 4          0            36.7           19.3              193.0       3450.0
# 5          0            39.3           20.6              190.0       3650.0
# ..       ...             ...            ...                ...          ...
# 338        2            47.2           13.7              214.0       4925.0
# 340        2            46.8           14.3              215.0       4850.0
# 341        2            50.4           15.7              222.0       5750.0
# 342        2            45.2           14.8              212.0       5200.0
# 343        2            49.9           16.1              213.0       5400.0
#
#      sex
# 0    0.0
# 1    1.0
# 2    1.0
# 4    1.0
# ...

# %%
X,y = pengu.drop("sex",axis=1), pengu["sex"].values

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=65)

from sklearn.linear_model import LogisticRegression

logmodel = LogisticRegression(max_iter=1500)
logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1500)

# %% [markdown]
# <h3>Wep service part</h3>

# %%
from flask import Flask, request, jsonify
app = Flask(__name__)

# %%
aa = pengu.drop("sex",axis=1).iloc[0]
aa["species" ] = 1
aa
# Out:
# species                 1.0
# bill_length_mm         39.1
# bill_depth_mm          18.7
# flipper_length_mm     181.0
# body_mass_g          3750.0
# Name: 0, dtype: float64

# %%
@app.get("/penguin/sample")
def get_example():
    return pengu.drop("sex",axis=1).iloc[0].to_json(orient="index")

# %%
@app.get("/penguin/explain")
def explane_sample():
    ornek = pengu.drop("sex",axis=1).iloc[0]
    ornek["species" ] = "Species are in the order of 0,1,2 representing Adelie,Chinstrap,Gentoo"
    ornek["sex" ] = "Sex is in the order of 0,1 representing Male,Female"
    ornek["bill_depth_mm" ] = "DVAR value between 13.1 and 21.5"
    ornek["bill_length_mm" ] = "DVAR value between 32.1 and 50.6"
    ornek["flipper_length_mm" ] = "DVAR value between 172.0 and 231.0"
    ornek["body_mass_g" ] = "DVAR value between 2700.0 and 6300.0"
    
    return ornek.to_json(orient="index")

# %%
@app.post("/penguin/evaluate")
def test_sample():
    if request.is_json:
        data = request.get_json()
        sample = pd.DataFrame([data])
        result = logmodel.predict(sample)
        if result[0] == 0:
            return jsonify({"sex": "Male"})
        else:
            return jsonify({"sex": "Female"})
        
    else:
        return jsonify({"error": "Request must be JSON"})

# %%
if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [25/Jul/2024 20:32:12] "GET /penguin/sample HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jul/2024 20:32:12] "POST /penguin/sex HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Jul/2024 20:33:09] "GET /penguin/sample HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jul/2024 20:33:39] "GET /penguin/sample HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jul/2024 20:33:47] "POST /penguin/predict HTTP/1.1" 404 -
# 127.0.0.1 - - [25/Jul/2024 20:34:36] "POST /penguin/evaluate HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jul/2024 20:34:50] "POST /penguin/evaluate HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jul/2024 20:34:54] "POST /penguin/evaluate HTTP/1.1" 200 -
# 127.0.0.1 - - [25/Jul/2024 20:35:07] "POST /penguin/evaluate HTTP/1.1" 200 -
# ...
